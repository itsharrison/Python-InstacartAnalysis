# %% [markdown]
# # 01. Importing Libraries

# %%
# importing libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Importing Data

# %%
# importing data
path = r"C:\Users\enthu\Desktop\Bootcamps\Instacart Basket Analysis"

# %%
path
# Out:
# 'C:\\Users\\enthu\\Desktop\\Bootcamps\\Instacart Basket Analysis'

# %%
# importing products.csv
df_prods = pd.read_csv(os.path.join(path, "Data", "Original Data", "products.csv"), index_col = False)

# %%
# importing orders_wrangled.csv
df_ords = pd.read_csv(os.path.join(path, "Data", "Prepared Data", "orders_wrangled.csv"), index_col = False)

# %% [markdown]
# # 03. Consistency Checks

# %%
# creating a dataframe for testing
df_test = pd.DataFrame()

# %%
# crteating a mixed type column
df_test['mix'] = ['a', 'b', 1, True]

# %%
df_test.head()
# Out:
#     mix
# 0     a
# 1     b
# 2     1
# 3  True

# %%
# checking for mixed data types
for col in df_test.columns.tolist():
  weird = (df_test[[col]].map(type) != df_test[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_test[weird]) > 0:
    print (col)
# Out:
# mix

# %%
# checking for missing values
df_prods.isnull().sum()
# Out:
# product_id        0
# product_name     16
# aisle_id          0
# department_id     0
# prices            0
# dtype: int64

# %%
# creating a new dataframe that contains null values
df_nan = df_prods[df_prods['product_name'].isnull() == True]

# %%
df_nan
# Out:
#        product_id product_name  aisle_id  department_id  prices
# 33             34          NaN       121             14    12.2
# 68             69          NaN        26              7    11.8
# 115           116          NaN        93              3    10.8
# 261           262          NaN       110             13    12.1
# 525           525          NaN       109             11     1.2
# 1511         1511          NaN        84             16    14.3
# 1780         1780          NaN       126             11    12.3
# 2240         2240          NaN        52              1    14.2
# 2586         2586          NaN       104             13    12.4
# 3159         3159          NaN       126             11    13.1
# 3230         3230          NaN       120             16    14.4
# 3736         3736          NaN        41              8    14.8
# 4283         4283          NaN        77              7    14.4
# 4790         4790          NaN        91             16    14.5
# ...

# %%
# number of rows in df_prods dataframe
df_prods.shape
# Out:
# (49693, 5)

# %%
# creating a new dataframe without missing values
df_prods_clean = df_prods[df_prods['product_name'].isnull() == False]

# %%
# checking the number of columns and rows that the df_prods_clean dataframe has
df_prods_clean.shape
# Out:
# (49677, 5)

# %%
# creating a new dataframe that contains only duplicate rows
df_dups = df_prods_clean[df_prods_clean.duplicated()]

# %%
df_dups
# Out:
#        product_id                                       product_name  \
# 462           462                  Fiber 4g Gummy Dietary Supplement
# 18459       18458                                         Ranger IPA
# 26810       26808               Black House Coffee Roasty Stout Beer
# 35309       35306  Gluten Free Organic Peanut Butter & Chocolate ...
# 35495       35491                            Adore Forever Body Wash
#
#        aisle_id  department_id  prices
# 462          70             11     4.8
# 18459        27              5     9.2
# 26810        27              5    13.4
# 35309       121             14     6.8
# 35495       127             11     9.9

# %%
# checking the current number of rows
df_prods_clean.shape
# Out:
# (49677, 5)

# %%
# creating a new dataframe that doesn't include the duplicates
df_prods_clean_no_dups = df_prods_clean.drop_duplicates()

# %%
df_prods_clean_no_dups.shape
# Out:
# (49672, 5)

# %% [markdown]
# # 04. Exercise 4.5

# %%
# descripotive analytics
df_ords.describe()
# Out:
#          Unnamed: 0      order_id       user_id  order_number  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710541e+06  1.710542e+06  1.029782e+05  1.715486e+01
# std    9.875817e+05  9.875817e+05  5.953372e+04  1.773316e+01
# min    0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    8.552705e+05  8.552715e+05  5.139400e+04  5.000000e+00
# 50%    1.710541e+06  1.710542e+06  1.026890e+05  1.100000e+01
# 75%    2.565812e+06  2.565812e+06  1.543850e+05  2.300000e+01
# max    3.421082e+06  3.421083e+06  2.062090e+05  1.000000e+02
#
#        orders_day_of_week  order_hour_of_day  days_since_prior_order
# count        3.421083e+06       3.421083e+06            3.214874e+06
# mean         2.776219e+00       1.345202e+01            1.111484e+01
# std          2.046829e+00       4.226088e+00            9.206737e+00
# min          0.000000e+00       0.000000e+00            0.000000e+00
# ...

# %% [markdown]
# 1. All columns seem to have the same count except for days_since_prior_order.
# 2. The min and max of orders_day_of_week are 0 and 6. They could represent Monday and Sunday, which is not too intuitive.
# 3. The min of order_hour_of_day is o, which doesn't make sense.

# %%
# looking for mixed data types
for col in df_ords.columns.tolist():
  weird = (df_ords[[col]].map(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_ords[weird]) > 0:
    print (col)

# %% [markdown]
# There are no mixed data types.

# %%
# looking for missing values in df_ords
df_ords.isnull().sum()
# Out:
# Unnamed: 0                     0
# order_id                       0
# user_id                        0
# eval_set                       0
# order_number                   0
# orders_day_of_week             0
# order_hour_of_day              0
# days_since_prior_order    206209
# dtype: int64

# %% [markdown]
# days_since_prior_order has 206209 missing values. Could have been caused by customers' first orders. This issue should be addressed since it's such a huge amount of missing data.

# %%
# creating a new dataframe that contains only NaN values
df_nan = df_ords[df_ords["days_since_prior_order"].isnull() == True]

# %%
df_nan
# Out:
#          Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0                 0   2539329        1    prior             1
# 11               11   2168274        2    prior             1
# 26               26   1374495        3    prior             1
# 39               39   3343014        4    prior             1
# 45               45   2717275        5    prior             1
# ...             ...       ...      ...      ...           ...
# 3420930     3420930    969311   206205    prior             1
# 3420934     3420934   3189322   206206    prior             1
# 3421002     3421002   2166133   206207    prior             1
# 3421019     3421019   2227043   206208    prior             1
# 3421069     3421069   3154581   206209    prior             1
#
#          orders_day_of_week  order_hour_of_day  days_since_prior_order
# 0                         2                  8                     NaN
# 11                        2                 11                     NaN
# ...

# %%
# creating a new dataframe that only contains order_number = 1
df_order_number_1 = df_ords[df_ords["order_number"] == 1]

# %%
df_order_number_1
# Out:
#          Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0                 0   2539329        1    prior             1
# 11               11   2168274        2    prior             1
# 26               26   1374495        3    prior             1
# 39               39   3343014        4    prior             1
# 45               45   2717275        5    prior             1
# ...             ...       ...      ...      ...           ...
# 3420930     3420930    969311   206205    prior             1
# 3420934     3420934   3189322   206206    prior             1
# 3421002     3421002   2166133   206207    prior             1
# 3421019     3421019   2227043   206208    prior             1
# 3421069     3421069   3154581   206209    prior             1
#
#          orders_day_of_week  order_hour_of_day  days_since_prior_order
# 0                         2                  8                     NaN
# 11                        2                 11                     NaN
# ...

# %%
# checking the miss values that the new dtaframe has
df_order_number_1.isnull().sum()
# Out:
# Unnamed: 0                     0
# order_id                       0
# user_id                        0
# eval_set                       0
# order_number                   0
# orders_day_of_week             0
# order_hour_of_day              0
# days_since_prior_order    206209
# dtype: int64

# %% [markdown]
# Both df_ords and df_order_number_1 have the same amount of missing values, which shows that the missing values were caused by first time customers. I would add a column that acts as a flag that addresses first orders.

# %%
# adding a new column to the dataframe that identifies first orders
df_ords['first_order'] = df_ords['days_since_prior_order'].isna()

# %%
df_ords
# Out:
#          Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0                 0   2539329        1    prior             1
# 1                 1   2398795        1    prior             2
# 2                 2    473747        1    prior             3
# 3                 3   2254736        1    prior             4
# 4                 4    431534        1    prior             5
# ...             ...       ...      ...      ...           ...
# 3421078     3421078   2266710   206209    prior            10
# 3421079     3421079   1854736   206209    prior            11
# 3421080     3421080    626363   206209    prior            12
# 3421081     3421081   2977660   206209    prior            13
# 3421082     3421082    272231   206209    train            14
#
#          orders_day_of_week  order_hour_of_day  days_since_prior_order  \
# 0                         2                  8                     NaN
# 1                         3                  7                    15.0
# ...

# %%
# looking for duplicates
df_ords_dups = df_prods[df_prods.duplicated()]

# %%
df_ords_dups
# Out:
#        product_id                                       product_name  \
# 462           462                  Fiber 4g Gummy Dietary Supplement
# 18459       18458                                         Ranger IPA
# 26810       26808               Black House Coffee Roasty Stout Beer
# 35309       35306  Gluten Free Organic Peanut Butter & Chocolate ...
# 35495       35491                            Adore Forever Body Wash
#
#        aisle_id  department_id  prices
# 462          70             11     4.8
# 18459        27              5     9.2
# 26810        27              5    13.4
# 35309       121             14     6.8
# 35495       127             11     9.9

# %% [markdown]
# df_ords doesn't have any duplicate values that need to be addressed.

# %%
# exporting df_prods
df_prods.to_csv(os.path.join(path, 'Data','Prepared Data', 'prods_consistensy_checked.csv'))

# %%
# exporting df_ords
df_ords.to_csv(os.path.join(path, 'Data','Prepared Data', 'orders_consistency_checked.csv'))
