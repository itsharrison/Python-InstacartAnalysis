# %% [markdown]
# ## 1. Importing Data

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Define the path
path = r"C:\Users\enthu\Desktop\Bootcamps\Instacart Basket Analysis"

# %%
path
# Out:
# 'C:\\Users\\enthu\\Desktop\\Bootcamps\\Instacart Basket Analysis'

# %%
# Import orders_products_combined pickle file
df_ords_prods_combined = pd.read_pickle(os.path.join(path, 'Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
# Check the shape of the dataframe
df_ords_prods_combined.shape
# Out:
# (32434489, 12)

# %%
df_ords_prods_combined.head()
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0           0   2539329        1    prior             1                   2
# 1           0   2539329        1    prior             1                   2
# 2           0   2539329        1    prior             1                   2
# 3           0   2539329        1    prior             1                   2
# 4           0   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered _merge
# 0          0   both
# ...

# %%
# Import the products data set 
df_prods = pd.read_csv(os.path.join(path, "Data", "Prepared Data", "prods_consistensy_checked.csv"), index_col = False)

# %%
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %% [markdown]
# ## 2. Merging Data

# %%
# Testing of merging df_ords_prods_combined dataframe and df_prods dataframe
df_merged_testing = df_ords_prods_combined.merge(df_prods, on = 'product_id')

# %%
df_merged_testing.head()
# Out:
#    Unnamed: 0_x  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0             0   2539329        1    prior             1                   2
# 1             1   2398795        1    prior             2                   3
# 2             2    473747        1    prior             3                   3
# 3             3   2254736        1    prior             4                   4
# 4             4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
# ...

# %% [markdown]
# "Unnamed: 0_x" and "Unnamed: 0_y" columns need to be dropped.

# %%
#Drop unnamed： 0 column in df_prods
df_prods = df_prods.drop(columns = ['Unnamed: 0'])

# %%
#Drop unnamed： 0 column in df_ords_prods_combined
df_ords_prods_combined = df_ords_prods_combined.drop(columns = ['Unnamed: 0'])

# %%
# Final merge after dropping columns
df_merged = df_ords_prods_combined.merge(df_prods, on = 'product_id')

# %%
df_merged.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
#    reordered _merge product_name  aisle_id  department_id  prices
# ...

# %%
df_merged['_merge'].value_counts()
# Out:
# _merge
# both          32434212
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
# Export data to pkl
df_merged.to_pickle(os.path.join(path, 'Data','Prepared Data', 'ords_prods_merge.pkl'))
